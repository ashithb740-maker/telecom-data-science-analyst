# %% [markdown]
# # Week 2 – Telecom Data Wrangling and Visualization
# **Author:** Ashith B

# %%
import pandas as pd
df=pd.read_csv('../data/raw/telecom_customer_usage_raw.csv')
df.head()

# %% [markdown]
# ## Cleaning
# The complete reproducible workflow is available in `src/telecom_data_wrangling.py`.

# %%
# Execute the script from the project root if required.
