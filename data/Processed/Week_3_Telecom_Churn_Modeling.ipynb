# %% [markdown]
# # Week 3 – Predictive Modeling and Machine Learning for Telecom Customer Churn
# **Author:** Ashith B

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('../data/raw/telecom_customer_usage_raw.csv')
df.head()

# %% [markdown]
# ## Modeling workflow
# 1. Clean data  2. Engineer features  3. Split data  4. Preprocess numeric/categorical variables  5. Train Logistic Regression and Decision Tree  6. Evaluate with accuracy, precision, recall, F1 and ROC-AUC  7. Validate with 5-fold stratified cross-validation.

# %%
# The full reproducible implementation is in ../src/telecom_churn_model.py
